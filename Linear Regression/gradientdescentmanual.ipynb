# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
X=2*np.random.rand(100,1)
y=4 + 3*X + np.random.randn(100,1)

plt.scatter(X,y,alpha=0.6)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Our fake data")
plt.show()

learning_rate=0.01
n_iteration=1000
m=len(X)

X_b=np.c_[np.ones((100,1)),X]

theta=np.random.randn(2,1)

for iteration in range(n_iteration):
    gradients=(2/m)*X_b.T@(X_b@theta-y)
    theta=theta-learning_rate*gradients

print("Parameters formed by gradient descent are slope-",theta[1][0],"y intercept optimal= ",theta[0][0])

X_new=np.array([[0],[2]])
X_new_b=np.c_[np.ones((2,1)),X_new]
y_predict=X_new_b@theta

plt.scatter(X,y,alpha=0.6)
plt.plot(X_new,y_predict,"r-",linewidth=2,label="Prediction")
plt.legend()
plt.title("Linear Regression from Scratch")
plt.show()
# Out:
# Parameters formed by gradient descent are slope- 2.8204434017416244 y intercept optimal=  4.158093763822134

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X,y)

print("Sklearn results")
print("the slope is ", model.coef_[0][0]," And y intercept is ", model.intercept_[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#       3 model=LinearRegression()
#       4 model.fit(X,y)
#
# ModuleNotFoundError: No module named 'sklearn'
