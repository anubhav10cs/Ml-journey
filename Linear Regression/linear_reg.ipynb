# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
X=2*np.random.rand(100,1)
y=4 + 3*X + np.random.randn(100,1)
model=LinearRegression()
model.fit(X,y)

print("Sklearn results")
print("the slope is ", model.coef_[0][0]," And y intercept is ", model.intercept_[0])
# Out:
# Sklearn results
# the slope is  2.7701133864384837  And y intercept is  4.215096157546747
